# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-340-g17c50046 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.2/78.2 GB disk)

# %%
# !unzip "/content/parkcar.zip"
# Out:
# Archive:  /content/parkcar.zip
#    creating: parkcar/
#    creating: parkcar/test/
#    creating: parkcar/test/images/
#   inflating: parkcar/test/images/parking-1_5-loop_mp4-0006_jpg.rf.91c14389ced839e5487bb0eb03da675f.jpg
#    creating: parkcar/test/labels/
#   inflating: parkcar/test/labels/parking-1_5-loop_mp4-0006_jpg.rf.91c14389ced839e5487bb0eb03da675f.txt
#    creating: parkcar/train/
#    creating: parkcar/train/images/
#   inflating: parkcar/train/images/parking-1_5-loop_mp4-0000_jpg.rf.aad701fa912036a8921974506a84f7e3.jpg
#   inflating: parkcar/train/images/parking-1_5-loop_mp4-0001_jpg.rf.0f0d34555dc0e365b97a7e20daa261a6.jpg
#   inflating: parkcar/train/images/parking-1_5-loop_mp4-0002_jpg.rf.ca7b1e4b8572e355ea835994b7f88a01.jpg
#   inflating: parkcar/train/images/parking-1_5-loop_mp4-0003_jpg.rf.930adb11f7b1759c8ecc2bb2b9ffb2c8.jpg
#   inflating: parkcar/train/images/parking-1_5-loop_mp4-0004_jpg.rf.5644e72fe1b02bc22d24a5ab0942f0b4.jpg
# ...

# %%
# Train YOLOv5s
# !python train.py --img 640 --batch 16 --epochs 10 --data /content/yolov5/data/data.yaml --weights yolov5s.pt --cache
# Out:
# 2024-07-13 15:19:50.275367: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-13 15:19:50.275417: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-13 15:19:50.276766: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Train with best pt
# !python train.py --img 640 --batch 16 --epochs 10 --data /content/yolov5/data/data.yaml --weights /content/yolov5/runs/train/exp3/weights/best.pt --cache
# Out:
# 2024-07-13 15:21:47.315201: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-13 15:21:47.315258: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-13 15:21:47.316664: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Train with epochs 100 for accuracy
# !python train.py --img 640 --batch 16 --epochs 100 --data /content/yolov5/data/data.yaml --weights /content/yolov5/runs/train/exp3/weights/best.pt --cache
# Out:
# 2024-07-13 15:23:35.761211: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-13 15:23:35.761260: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-13 15:23:35.762571: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp5/weights/best.pt --img 640 --conf 0.25 --source /content/parkcar.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp5/weights/best.pt'], source=/content/parkcar.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-340-g17c50046 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/parkcar.jpg: 640x640 164 parking-carss, 11.5ms
# Speed: 0.6ms pre-process, 11.5ms inference, 569.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp3/weights/best.pt --img 640 --conf 0.25 --source /content/parkinglot.mp4
# Out:
# detect: weights=['/content/yolov5/runs/train/exp3/weights/best.pt'], source=/content/parkinglot.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-340-g17c50046 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/1117) /content/parkinglot.mp4: 640x480 (no detections), 56.8ms
# video 1/1 (2/1117) /content/parkinglot.mp4: 640x480 (no detections), 8.6ms
# video 1/1 (3/1117) /content/parkinglot.mp4: 640x480 (no detections), 8.5ms
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp3/weights/best.pt --img 640 --conf 0.25 --source /content/parking_crop.mp4
# Out:
# detect: weights=['/content/yolov5/runs/train/exp3/weights/best.pt'], source=/content/parking_crop.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-340-g17c50046 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/849) /content/parking_crop.mp4: 640x544 (no detections), 78.3ms
# video 1/1 (2/849) /content/parking_crop.mp4: 640x544 (no detections), 11.1ms
# video 1/1 (3/849) /content/parking_crop.mp4: 640x544 (no detections), 11.1ms
# ...
